# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/portu_banking_final.csv')
X = dataset.iloc[:,[2,3]].values
y = dataset.iloc[:, 4].values
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dataset
# Out:
#       age          job  marital  ... euribor3m nr_employed  y
# 0      44  blue-collar  married  ...     4.963      5228.1  0
# 1      53   technician  married  ...     4.021      5195.8  0
# 2      28   management   single  ...     0.729      4991.6  1
# 3      39     services  married  ...     1.405      5099.1  0
# 4      55      retired  married  ...     0.869      5076.2  1
# ...    ..          ...      ...  ...       ...         ... ..
# 41183  59      retired  married  ...     4.866      5228.1  0
# 41184  31    housemaid  married  ...     4.860      5191.0  0
# 41185  42       admin.   single  ...     4.857      5191.0  0
# 41186  48   technician  married  ...     0.742      5017.5  0
# 41187  25      student   single  ...     4.859      5191.0  0
#
# [41188 rows x 21 columns]

# %% [markdown]
# The significance of y column is whether the client will subscribe or not and the value counts are 0 and 1.

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  object
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  float64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp_var_rate    41188 non-null  float64
#  16  cons_price_idx  41188 non-null  float64
# ...

# %%
dataset.dtypes
# Out:
# age                object
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays             float64
# previous            int64
# poutcome           object
# emp_var_rate      float64
# cons_price_idx    float64
# cons_conf_idx     float64
# euribor3m         float64
# nr_employed       float64
# y                   int64
# dtype: object

# %%
display(dataset.head())
# Out:
#   age          job  marital  ... euribor3m nr_employed  y
# 0  44  blue-collar  married  ...     4.963      5228.1  0
# 1  53   technician  married  ...     4.021      5195.8  0
# 2  28   management   single  ...     0.729      4991.6  1
# 3  39     services  married  ...     1.405      5099.1  0
# 4  55      retired  married  ...     0.869      5076.2  1
#
# [5 rows x 21 columns]

# %%
X = dataset.iloc[:, :-1]
display(X)

Y = dataset.iloc[:, -1]
display(Y)
# Out:
#       age          job  marital  ... cons_conf_idx euribor3m nr_employed
# 0      44  blue-collar  married  ...         -36.1     4.963      5228.1
# 1      53   technician  married  ...         -42.0     4.021      5195.8
# 2      28   management   single  ...         -39.8     0.729      4991.6
# 3      39     services  married  ...         -47.1     1.405      5099.1
# 4      55      retired  married  ...         -31.4     0.869      5076.2
# ...    ..          ...      ...  ...           ...       ...         ...
# 41183  59      retired  married  ...         -41.8     4.866      5228.1
# 41184  31    housemaid  married  ...         -36.4     4.860      5191.0
# 41185  42       admin.   single  ...         -36.4     4.857      5191.0
# 41186  48   technician  married  ...         -26.9     0.742      5017.5
# 41187  25      student   single  ...         -36.4     4.859      5191.0
#
# [41188 rows x 20 columns]
# 0        0
# 1        0
# 2        1
# 3        0
# 4        1
# ...

# %%
dataset.groupby(['y','job','marital','education']).mean()
# Out:
#                                                duration  ...  nr_employed
# y job         marital  education                         ...
# 0 ADMIN.      married  university.degree     744.000000  ...  5191.000000
#               single   university.degree     530.000000  ...  5191.000000
#   BLUE-COLLAR married  basic.4y                5.000000  ...  5099.100000
#   HOUSEMAID   divorced basic.4y               84.000000  ...  5195.800000
#   MANAGEMENT  M        university.degree    1225.000000  ...  5076.200000
# ...                                                 ...  ...          ...
# 1 unknown     single   professional.course  2029.000000  ...  5228.100000
#                        university.degree     633.666667  ...  5067.422222
#                        unknown               712.500000  ...  5104.250000
#               unknown  university.degree     617.000000  ...  5191.000000
#                        unknown               541.000000  ...  5228.100000
#
# ...

# %%
display(dataset.describe())
# Out:
#            duration      campaign  ...   nr_employed             y
# count  41188.000000  41188.000000  ...  41188.000000  41188.000000
# mean     258.285010      2.567593  ...   5167.035911      0.112654
# std      259.279249      2.770014  ...     72.251528      0.316173
# min        0.000000      1.000000  ...   4963.600000      0.000000
# 25%      102.000000      1.000000  ...   5099.100000      0.000000
# 50%      180.000000      2.000000  ...   5191.000000      0.000000
# 75%      319.000000      3.000000  ...   5228.100000      0.000000
# max     4918.000000     56.000000  ...   5228.100000      1.000000
#
# [8 rows x 10 columns]

# %%
dataset.groupby(['job','y']).count()
# Out:
#                   age  marital  ...  euribor3m  nr_employed
# job           y                 ...
# ADMIN.        0     2        2  ...          2            2
# BLUE-COLLAR   0     1        1  ...          1            1
# HOUSEMAID     0     1        1  ...          1            1
# MANAGEMENT    0     1        1  ...          1            1
# RETIRED       0     2        2  ...          2            2
#               1     1        1  ...          1            1
# SERVICES      0     3        3  ...          3            3
# STUDENT       1     2        2  ...          2            2
# TECHNICIAN    0     1        1  ...          1            1
# UNKNOWN       0     1        1  ...          1            1
# admin.        0  9068     9068  ...       9068         9068
#               1  1352     1352  ...       1352         1352
# blue-collar   0  8615     8615  ...       8615         8615
#               1   638      638  ...        638          638
# ...

# %%
plt.bar(dataset['job'],dataset['y'])
# Out:
# <BarContainer object of 41188 artists>

# %%
jobdummy = pd.get_dummies(dataset['job'])

# %%
data1 = pd.concat([dataset,jobdummy],axis=1)
data1.head()
# Out:
#   age          job  marital  ... technician unemployed unknown
# 0  44  blue-collar  married  ...          0          0       0
# 1  53   technician  married  ...          1          0       0
# 2  28   management   single  ...          0          0       0
# 3  39     services  married  ...          0          0       0
# 4  55      retired  married  ...          0          0       0
#
# [5 rows x 42 columns]

# %%
data1 = data1.drop('job', axis=1)
data1.head()
# Out:
#   age  marital          education  ... technician unemployed unknown
# 0  44  married           basic.4y  ...          0          0       0
# 1  53  married            unknown  ...          1          0       0
# 2  28   single  university.degree  ...          0          0       0
# 3  39  married        high.school  ...          0          0       0
# 4  55  married           basic.4y  ...          0          0       0
#
# [5 rows x 41 columns]

# %%
maritaldummy = pd.get_dummies(dataset['marital'])

# %%
data2 = pd.concat([data1,maritaldummy],axis=1)
data2.head()
# Out:
#   age  marital          education  default  ... divorced married single unknown
# 0  44  married           basic.4y  unknown  ...        0       1      0       0
# 1  53  married            unknown       no  ...        0       1      0       0
# 2  28   single  university.degree       no  ...        0       0      1       0
# 3  39  married        high.school       no  ...        0       1      0       0
# 4  55  married           basic.4y       no  ...        0       1      0       0
#
# [5 rows x 48 columns]

# %%
data2 = data2.drop('marital', axis=1)
data2.head()
# Out:
#   age          education  default housing  ... divorced married single unknown
# 0  44           basic.4y  unknown     yes  ...        0       1      0       0
# 1  53            unknown       no      no  ...        0       1      0       0
# 2  28  university.degree       no     yes  ...        0       0      1       0
# 3  39        high.school       no      no  ...        0       1      0       0
# 4  55           basic.4y       no     yes  ...        0       1      0       0
#
# [5 rows x 47 columns]

# %%
educationdummy = pd.get_dummies(dataset['education'])

# %%
data3 = pd.concat([data2,educationdummy],axis=1)
data3.head()
# Out:
#   age          education  ... university.degree unknown
# 0  44           basic.4y  ...                 0       0
# 1  53            unknown  ...                 0       1
# 2  28  university.degree  ...                 1       0
# 3  39        high.school  ...                 0       0
# 4  55           basic.4y  ...                 0       0
#
# [5 rows x 58 columns]

# %%
data3 = data3.drop('education', axis=1)
data3.head()
# Out:
#   age  default housing  ... professional.course university.degree unknown
# 0  44  unknown     yes  ...                   0                 0       0
# 1  53       no      no  ...                   0                 0       1
# 2  28       no     yes  ...                   0                 1       0
# 3  39       no      no  ...                   0                 0       0
# 4  55       no     yes  ...                   0                 0       0
#
# [5 rows x 57 columns]

# %%
loandummy = pd.get_dummies(dataset['loan'])

# %%
data4 = pd.concat([data3,loandummy],axis=1)
data4.head()
# Out:
#   age  default housing loan  ... unknown no unknown  yes
# 0  44  unknown     yes   no  ...       0  1       0    0
# 1  53       no      no   no  ...       1  1       0    0
# 2  28       no     yes   no  ...       0  1       0    0
# 3  39       no      no   no  ...       0  1       0    0
# 4  55       no     yes   no  ...       0  1       0    0
#
# [5 rows x 60 columns]

# %%
data4 = data4.drop('loan', axis=1)
data4.head()
# Out:
#   age  default housing   contact  ...  unknown no  unknown  yes
# 0  44  unknown     yes  cellular  ...        0  1        0    0
# 1  53       no      no  cellular  ...        1  1        0    0
# 2  28       no     yes  cellular  ...        0  1        0    0
# 3  39       no      no  cellular  ...        0  1        0    0
# 4  55       no     yes  cellular  ...        0  1        0    0
#
# [5 rows x 59 columns]

# %%
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 59 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  41188 non-null  object
#  1   default              41188 non-null  object
#  2   housing              41188 non-null  object
#  3   contact              41188 non-null  object
#  4   month                41188 non-null  object
#  5   day_of_week          41188 non-null  object
#  6   duration             41188 non-null  int64
#  7   campaign             41188 non-null  int64
#  8   pdays                41188 non-null  float64
#  9   previous             41188 non-null  int64
#  10  poutcome             41188 non-null  object
#  11  emp_var_rate         41188 non-null  float64
#  12  cons_price_idx       41188 non-null  float64
#  13  cons_conf_idx        41188 non-null  float64
#  14  euribor3m            41188 non-null  float64
# ...

# %%
data4['age'].value_counts()
# Out:
# 31       1530
# 32       1456
# 33       1452
# 35       1431
# 36       1408
#          ...
# 30-40       1
# 30-32       1
# 35-30       1
# 18-25       1
# 35-40       1
# Name: age, Length: 159, dtype: int64

# %%
def ageconvert(age):
  if type(age)==int:
    return age
  elif age.find('-')==-1:
    return int(age)
  else:
    split_age = age.split('-')
    ll=int(split_age[0])
    ul=int(split_age[1])
    return (ll+ul)/2

data4['age'] = data4['age'].apply(ageconvert)
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 59 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  41188 non-null  float64
#  1   default              41188 non-null  object
#  2   housing              41188 non-null  object
#  3   contact              41188 non-null  object
#  4   month                41188 non-null  object
#  5   day_of_week          41188 non-null  object
#  6   duration             41188 non-null  int64
#  7   campaign             41188 non-null  int64
#  8   pdays                41188 non-null  float64
#  9   previous             41188 non-null  int64
#  10  poutcome             41188 non-null  object
#  11  emp_var_rate         41188 non-null  float64
#  12  cons_price_idx       41188 non-null  float64
#  13  cons_conf_idx        41188 non-null  float64
#  14  euribor3m            41188 non-null  float64
# ...

# %%
data4=data4.drop(['default','housing','contact','month','day_of_week','poutcome'], axis=1)
data4.head()
# Out:
#     age  duration  campaign  pdays  ...  unknown  no  unknown  yes
# 0  44.0       210         1  999.0  ...        0   1        0    0
# 1  53.0       138         1  999.0  ...        1   1        0    0
# 2  28.0       339         3    6.0  ...        0   1        0    0
# 3  39.0       185         2  999.0  ...        0   1        0    0
# 4  55.0       137         1    3.0  ...        0   1        0    0
#
# [5 rows x 53 columns]

# %%
X = data4.iloc[:, :-1]
display(X)

Y = data4.iloc[:, -1]
display(Y)
# Out:
#         age  duration  campaign  pdays  ...  university.degree  unknown  no  unknown
# 0      44.0       210         1  999.0  ...                  0        0   1        0
# 1      53.0       138         1  999.0  ...                  0        1   1        0
# 2      28.0       339         3    6.0  ...                  1        0   1        0
# 3      39.0       185         2  999.0  ...                  0        0   1        0
# 4      55.0       137         1    3.0  ...                  0        0   1        0
# ...     ...       ...       ...    ...  ...                ...      ...  ..      ...
# 41183  59.0       222         1  999.0  ...                  0        0   0        0
# 41184  31.0       196         2  999.0  ...                  0        0   1        0
# 41185  42.0        62         3  999.0  ...                  1        0   0        0
# 41186  48.0       200         2  999.0  ...                  0        0   0        0
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.25, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression(random_state=0)
classifier.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=0, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
Y_pred = classifier.predict(X_test)

# %%
Y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=uint8)

# %%
from sklearn import metrics
from sklearn.metrics import plot_confusion_matrix, accuracy_score
print('Accuracy', accuracy_score(y_test,Y_pred))
print(metrics.confusion_matrix(y_test, Y_pred, labels=[0,1]))
print(metrics.classification_report(y_test, Y_pred, labels=[0,1]))
# Out:
# Accuracy 1.0
# [[8731    0]
#  [   0 1566]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      8731
#            1       1.00      1.00      1.00      1566
#
#     accuracy                           1.00     10297
#    macro avg       1.00      1.00      1.00     10297
# weighted avg       1.00      1.00      1.00     10297

# %%
from sklearn.metrics import plot_confusion_matrix, accuracy_score

print( "The accuracy of the Model",accuracy_score(y_test, Y_pred))

class_names = [0,1]

titles_options = [("Confusion matrix, without normalization", None),
                  ("Normalized confusion matrix", 'true')]
for title, normalize in titles_options:
    disp = plot_confusion_matrix(classifier, X_test, y_test,
                                 display_labels=class_names,
                                 cmap=plt.cm.Blues,
                                 normalize=normalize)
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)

plt.show()
# Out:
# The accuracy of the Model 1.0
# Confusion matrix, without normalization
# [[8731    0]
#  [   0 1566]]
# Normalized confusion matrix
# [[1. 0.]
#  [0. 1.]]

# %%
A = data['click_time'][0]
print(A)
